# %%
import numpy as np 
import random 
import torch 
import torch.nn as nn 
import torch.optim as optim 

# Define your neural network architecture. 
# In this case, input_size = 9 (9 eyes), output_size = 4 (4 kinds of movements). 
class QNetwork(nn.Module): 
    def __init__(self, input_size, output_size): 
        super().__init__() 
        self.fc1 = nn.Linear(input_size, 128) 
        self.fc2 = nn.Linear(128, 64) 
        self.fc3 = nn.Linear(64, output_size) 

    # This line defines the forward method for the QNetwork class, 
    # which specifies how data flows through the network during the forward pass. 
    def forward(self, x): 
        # ReLU: Rectified Linear Unit 
        # It applies ReLU activation function to the output of the 1st fully connected layer (fc1). 
        x = torch.relu(self.fc1(x)) # torch.nn.functional.relu 
        # It applies ReLU activation function to the output of the 2nd fully connected layer (fc2). 
        x = torch.relu(self.fc2(x)) # torch.nn.functional.relu 
        # It returns the output of the 3rd fully connected layer (fc3) without using activation function. 
        return self.fc3(x) 

# Define the Deep Q-Learning agent. 
class DQNAgent: 
    def __init__(self, state_size, action_size, gamma = 0.99, epsilon = 1.0, epsilon_decay = 0.995, epsilon_min = 0.01): 
        self.state_size = state_size # state_size: 9 eyes 
        self.action_size = action_size # action_size: 4 kinds of movements 
        self.gamma = gamma 
        self.epsilon = epsilon 
        self.epsilon_decay = epsilon_decay 
        self.epsilon_min = epsilon_min 
        
        # state_size, action_size: 9 eyes, 4 kinds of movements 
        self.q_network = QNetwork(state_size, action_size) 
        self.optimizer = optim.Adam(self.q_network.parameters(), lr = 0.001) 
    
    # The select_action method of the DQNAgent class returns 
    # the index of the action with the highest Q-value. 
    def select_action(self, state): 
        if np.random.rand() < self.epsilon: 
            return random.randrange(self.action_size) 
        with torch.no_grad(): 
            state = torch.tensor(state, dtype = torch.float32) 
            q_values = self.q_network(state) 
            return np.argmax(q_values.numpy()) 
    
    def train(self, state, action, reward, next_state, done): 
        state = torch.tensor(state, dtype = torch.float32) 
        next_state = torch.tensor(next_state, dtype = torch.float32) 
        q_values = self.q_network(state) # 2. Input the data into the model. 
        next_q_values = self.q_network(next_state) 
        target = q_values.clone() 
        target[0][action] = reward + self.gamma * torch.max(next_q_values) 
        loss = nn.MSELoss()(q_values, target) # 3. Calculate loss. 
        self.optimizer.zero_grad() # 1. Clear the gradient. 
        loss.backward() # 4. Calculate the gradient. [Backpropogation] 
        self.optimizer.step() # 5. Do gradient Descent. [Update the parameter.] 
        if self.epsilon > self.epsilon_min: 
            self.epsilon *= self.epsilon_decay 

# Define your 2D environment class. 
class Environment: 
    def __init__(self, num_red_apples, num_green_poisonous_things): 
        
        # Define the number of eyes and the number of values each eye senses. 
        self.num_eyes = 9 
        self.num_values_per_eye = 3 
        self.max_visibility_distance = 10.0 # Adjust as needed 
        
        # Define the boundaries of the environment. 
        self.x_min = 0 
        self.x_max = 100 # Adjust as needed 
        self.y_min = 0 
        self.y_max = 100 # Adjust as needed 
        
        # Initialize the environment state with maximum visibility distances. 
        # self.initial_state is a 3 * 9 array with 10.0 in each element. 
        self.initial_state = np.full((self.num_values_per_eye, self.num_eyes), self.max_visibility_distance) 

        # Define the number of red apples and green poisonous things. 
        self.num_red_apples = num_red_apples 
        self.num_green_poisonous_things = num_green_poisonous_things 
        
        # Place the red apples and green poisonous things randomly.  
        self.red_apple_positions = self._generate_random_positions(self.num_red_apples) 
        self.green_poisonous_thing_positions = self._generate_random_positions(self.num_green_poisonous_things) 
        
        # Initialize the agent's position 
        self.agent_position = [50, 50]  # Starting position of the agent 
        
    def _generate_random_positions(self, num_positions): 
        positions = [] 
        for i in range(num_positions): 
            position = [random.randint(self.x_min, self.x_max), random.randint(self.y_min, self.y_max)] 
            while position in positions: 
                position = [random.randint(self.x_min, self.x_max), random.randint(self.y_min, self.y_max)] 
            positions.append(position) 
        return positions 
    
    def _get_agent_positions(self): 
        # Return the current position of the agent 
        return [self.agent_position] 
        
    def step(self, action): 
        
        # Define the mapping between action indices and action strings. 
        action_mapping = { 
            0: "move_left", 
            1: "move_right", 
            2: "move_up", 
            3: "move_down" 
        } 
        
        # Implement the step function to update the environment based on the chosen action 

        # 1. Update the state (no state change in this simple example) 
        next_state = self.initial_state 

        # 2. Calculate the reward 
        reward = 0 
        
        # Check if the agent collects a red apple 
        for i in range(self.num_red_apples): 
            if self.red_apple_positions[i] in self._get_agent_positions(): 
                reward = reward + 1.0 # Add a positive reward for collecting a red apple 
                self.red_apple_positions[i] = None # Remove the collected red apple from the environment 
                break # Exit the loop once a red apple is collected 
                
        # Check if the agent collides with a green poisonous thing 
        for i in range(self.num_green_poisonous_things): 
            if self.green_poisonous_thing_positions[i] in self._get_agent_positions(): 
                reward = reward - 1.0 # Add a negative reward for colliding with a green poisonous thing 
                done = True # Terminate the episode 
                break # Exit the loop once a green poisonous thing is collided with 

        # 3. Determine if the episode is done 
        done = False 

        # Update the agent's position based on the chosen action 
        if action == 0 and self.agent_position[0] > self.x_min: 
            self.agent_position[0] -= 1 # Move left 
            
        elif action == 1 and self.agent_position[0] < self.x_max: 
            self.agent_position[0] += 1 # Move right 
            
        elif action == 2 and self.agent_position[1] < self.y_max: 
            self.agent_position[1] += 1 # Move up 
            
        elif action == 3 and self.agent_position[1] > self.y_min: 
            self.agent_position[1] -= 1 # Move down 
        
        # Check if the action takes the agent outside the boundaries 
        if action == 0 and self.agent_position[0] <= self.x_min: 
            done = True # Terminate the episode 
            
        elif action == 1 and self.agent_position[0] >= self.x_max: 
            done = True # Terminate the episode 
            
        elif action == 2 and self.agent_position[1] >= self.y_max: 
            done = True # Terminate the episode 
            
        elif action == 3 and self.agent_position[1] <= self.y_min: 
            done = True # Terminate the episode 
            
        # Get the corresponding action string from the mapping 
        action_string = action_mapping.get(action, "unknown") 
        
        # Return the next_state, reward, and whether the episode is done 
        return next_state, reward, done, action_string, self.agent_position 
        # return next_state, reward, done, action_string, self.agent_position, self.red_apple_positions, self.green_poisonous_thing_positions 

# Create an instance of your 2D environment 
# 351: # of red apples 
# 289: # of green poisonous things 
env = Environment(351, 289) 
    
# Define your 2D environment and the training loop 
def train_dqn(num_episodes, env): 
    state_size = 9 # Adjust according to your state representation (9 eyes) 
    action_size = 4 # Number of possible actions (4 kinds of movements) 

    # state_size = 9 eyes 
    # action_size = 4 kinds of movements 
    agent = DQNAgent(state_size, action_size) 

    for episode in range(num_episodes): 
        state = env.initial_state # Initialize the environment state (3 * 9 array, elements: 10.0) 
        total_reward = 0 
        done = False 
        
        print(f"Episode: {episode + 1}") 

        while not done: 
            action = agent.select_action(state) 
            next_state, reward, done, action_string, agent_position = env.step(action)  # Use the environment you defined 
            # next_state, reward, done, action_string, agent_position, red_apple_positions, green_poisonous_thing_positions = env.step(action)  # Use the environment you defined 

            agent.train(state, action, reward, next_state, done) 
            state = next_state 
            total_reward += reward 
            print(f"Action: {action_string}, Done: {done}, Reward: {reward}, Agent Position: {agent_position}") 
            # print(f"Action: {action_string}, Done: {done}, Reward: {reward}, Agent Position: {agent_position}\n") 
            # print(f"Red Position: {red_apple_positions}, \n\nGreen Positions: {green_poisonous_thing_positions}\n") 
            
        print(f"Total Reward: {total_reward}\n") 

# Main training loop 
if __name__ == "__main__": 
    num_episodes = 100 # Adjust the number of episodes as needed 
    train_dqn(num_episodes, env)
# Out:
# Episode: 1
# Action: move_right, Done: False, Reward: 0, Agent Position: [51, 50]
# Action: move_right, Done: False, Reward: 0, Agent Position: [52, 50]
# Action: move_down, Done: False, Reward: 0, Agent Position: [52, 49]
# Action: move_up, Done: False, Reward: 0, Agent Position: [52, 50]
# Action: move_right, Done: False, Reward: 0, Agent Position: [53, 50]
# Action: move_down, Done: False, Reward: 0, Agent Position: [53, 49]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_up, Done: False, Reward: 0, Agent Position: [54, 50]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 48]
# Action: move_up, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 49]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 49]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 48]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 48]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 47]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 48]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 49]
# Action: move_down, Done: False, Reward: 0, Agent Position: [53, 48]
# Action: move_down, Done: False, Reward: 0, Agent Position: [53, 47]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 47]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 46]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 45]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 45]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 44]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [55, 43]
# Action: move_right, Done: False, Reward: 0, Agent Position: [56, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [56, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [58, 44]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [59, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [59, 43]
# Action: move_left, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [55, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [54, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [56, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [56, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 42]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 43]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [56, 44]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_up, Done: False, Reward: 0, Agent Position: [57, 45]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 43]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [58, 44]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 42]
# Action: move_up, Done: False, Reward: 0, Agent Position: [58, 43]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 42]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 40]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [57, 40]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [55, 39]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 38]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [53, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 38]
# Action: move_up, Done: False, Reward: 0, Agent Position: [54, 39]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 39]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 38]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 37]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 36]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 36]
# Action: move_left, Done: False, Reward: -1.0, Agent Position: [53, 36]
# Action: move_up, Done: False, Reward: 0, Agent Position: [53, 37]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 37]
# Action: move_up, Done: False, Reward: 0, Agent Position: [54, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 38]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 39]
# Action: move_right, Done: False, Reward: 0, Agent Position: [56, 39]
# Action: move_up, Done: False, Reward: 0, Agent Position: [56, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [59, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [60, 40]
# Action: move_right, Done: False, Reward: 0, Agent Position: [61, 40]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 39]
# Action: move_right, Done: False, Reward: -1.0, Agent Position: [61, 39]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 39]
# Action: move_down, Done: False, Reward: 0, Agent Position: [62, 38]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [62, 37]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [63, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [64, 38]
# Action: move_up, Done: False, Reward: 0, Agent Position: [64, 39]
# Action: move_up, Done: False, Reward: 0, Agent Position: [64, 40]
# Action: move_down, Done: False, Reward: 0, Agent Position: [64, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [63, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [62, 39]
# Action: move_right, Done: False, Reward: 0, Agent Position: [63, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [62, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 39]
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 39]
# Action: move_down, Done: False, Reward: -1.0, Agent Position: [60, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [61, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 38]
# Action: move_right, Done: False, Reward: 0, Agent Position: [61, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [59, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [58, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 38]
# Action: move_down, Done: False, Reward: 0, Agent Position: [57, 37]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 37]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 37]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 37]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 36]
# Action: move_down, Done: False, Reward: 0, Agent Position: [58, 35]
# Action: move_right, Done: False, Reward: 0, Agent Position: [59, 35]
# Action: move_right, Done: False, Reward: 0, Agent Position: [60, 35]
# Action: move_right, Done: False, Reward: 0, Agent Position: [61, 35]
# Action: move_up, Done: False, Reward: 0, Agent Position: [61, 36]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 35]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 34]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [63, 33]
# Action: move_down, Done: False, Reward: 0, Agent Position: [63, 32]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [63, 31]
# Action: move_right, Done: False, Reward: 0, Agent Position: [64, 31]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [64, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [63, 30]
# Action: move_down, Done: False, Reward: 0, Agent Position: [63, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [64, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [65, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [66, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [67, 29]
# Action: move_down, Done: False, Reward: 0, Agent Position: [67, 28]
# Action: move_right, Done: False, Reward: 0, Agent Position: [68, 28]
# Action: move_right, Done: False, Reward: 0, Agent Position: [69, 28]
# Action: move_up, Done: False, Reward: 0, Agent Position: [69, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [70, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [71, 29]
# Action: move_down, Done: False, Reward: 0, Agent Position: [71, 28]
# Action: move_left, Done: False, Reward: 0, Agent Position: [70, 28]
# Action: move_right, Done: False, Reward: 0, Agent Position: [71, 28]
# Action: move_right, Done: False, Reward: 0, Agent Position: [72, 28]
# Action: move_up, Done: False, Reward: 0, Agent Position: [72, 29]
# Action: move_up, Done: False, Reward: 0, Agent Position: [72, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [71, 30]
# Action: move_right, Done: False, Reward: 0, Agent Position: [72, 30]
# Action: move_down, Done: False, Reward: 0, Agent Position: [72, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [73, 29]
# Action: move_left, Done: False, Reward: 0, Agent Position: [72, 29]
# Action: move_left, Done: False, Reward: 0, Agent Position: [71, 29]
# Action: move_left, Done: False, Reward: 0, Agent Position: [70, 29]
# Action: move_up, Done: False, Reward: 0, Agent Position: [70, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [69, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [68, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [67, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [66, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [65, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [64, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [63, 30]
# Action: move_down, Done: False, Reward: 0, Agent Position: [63, 29]
# Action: move_left, Done: False, Reward: 0, Agent Position: [62, 29]
# Action: move_down, Done: False, Reward: 0, Agent Position: [62, 28]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 28]
# Action: move_up, Done: False, Reward: 0, Agent Position: [61, 29]
# Action: move_up, Done: False, Reward: 0, Agent Position: [61, 30]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 29]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 29]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 30]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 31]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 32]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 33]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 33]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 33]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [59, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [58, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [57, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [55, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [52, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [51, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [50, 34]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [49, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [48, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [47, 34]
# Action: move_right, Done: False, Reward: 0, Agent Position: [48, 34]
# Action: move_left, Done: False, Reward: 0, Agent Position: [47, 34]
# Action: move_down, Done: False, Reward: 0, Agent Position: [47, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [48, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [49, 33]
# Action: move_down, Done: False, Reward: -1.0, Agent Position: [49, 32]
# Action: move_right, Done: False, Reward: 0, Agent Position: [50, 32]
# Action: move_right, Done: False, Reward: 0, Agent Position: [51, 32]
# Action: move_right, Done: False, Reward: 0, Agent Position: [52, 32]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [52, 31]
# Action: move_up, Done: False, Reward: 0, Agent Position: [52, 32]
# Action: move_right, Done: False, Reward: 0, Agent Position: [53, 32]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 32]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 31]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 31]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [52, 31]
# Action: move_down, Done: False, Reward: 0, Agent Position: [52, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [51, 30]
# Action: move_right, Done: False, Reward: 0, Agent Position: [52, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [51, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [50, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [49, 30]
# Action: move_right, Done: False, Reward: 0, Agent Position: [50, 30]
# Action: move_left, Done: False, Reward: 0, Agent Position: [49, 30]
# Action: move_up, Done: False, Reward: 0, Agent Position: [49, 31]
# Action: move_right, Done: False, Reward: 0, Agent Position: [50, 31]
# Action: move_left, Done: False, Reward: 0, Agent Position: [49, 31]
# Action: move_left, Done: False, Reward: 0, Agent Position: [48, 31]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 32]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 33]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 34]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 35]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [48, 36]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 37]
# Action: move_up, Done: False, Reward: 0, Agent Position: [48, 38]
# Action: move_left, Done: False, Reward: 0, Agent Position: [47, 38]
# Action: move_up, Done: False, Reward: 0, Agent Position: [47, 39]
# Action: move_up, Done: False, Reward: 0, Agent Position: [47, 40]
# Action: move_left, Done: False, Reward: 0, Agent Position: [46, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [46, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [46, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [46, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [45, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [44, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [43, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [42, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [42, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [43, 42]
# Action: move_left, Done: False, Reward: 0, Agent Position: [42, 42]
# Action: move_left, Done: False, Reward: 0, Agent Position: [41, 42]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [40, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [40, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [41, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [42, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [43, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [44, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [45, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [46, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [47, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [48, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [49, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [49, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [50, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [51, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [52, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [53, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [54, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 40]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 39]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 38]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 37]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 36]
# Action: move_down, Done: False, Reward: -1.0, Agent Position: [54, 35]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 34]
# Action: move_down, Done: False, Reward: 0, Agent Position: [54, 33]
# Action: move_right, Done: False, Reward: 0, Agent Position: [55, 33]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 32]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 31]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 32]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 33]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 34]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 35]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 36]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 37]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 38]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 39]
# Action: move_right, Done: False, Reward: 0, Agent Position: [56, 39]
# Action: move_up, Done: False, Reward: 0, Agent Position: [56, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [56, 41]
# Action: move_left, Done: False, Reward: 0, Agent Position: [55, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [55, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [55, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [56, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [57, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [58, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [59, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [60, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [61, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [63, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [64, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [65, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [66, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [67, 41]
# Action: move_right, Done: False, Reward: 0, Agent Position: [68, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [68, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [69, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [70, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [71, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [72, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [73, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [74, 42]
# Action: move_right, Done: False, Reward: 0, Agent Position: [75, 42]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 41]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 40]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 39]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 38]
# Action: move_up, Done: False, Reward: -1.0, Agent Position: [75, 39]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 40]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 41]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 42]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 43]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 42]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 43]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 44]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 45]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 46]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 47]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 48]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 49]
# Action: move_up, Done: False, Reward: -1.0, Agent Position: [75, 50]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 51]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 52]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 53]
# Action: move_up, Done: False, Reward: -1.0, Agent Position: [75, 54]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 55]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 56]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [75, 57]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 58]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 59]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 60]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [75, 61]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 62]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 63]
# Action: move_up, Done: False, Reward: 0, Agent Position: [75, 64]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [75, 63]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 62]
# Action: move_down, Done: False, Reward: 0, Agent Position: [75, 61]
# Action: move_left, Done: False, Reward: 0, Agent Position: [74, 61]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 60]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 59]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 58]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 57]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 56]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 55]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 54]
# Action: move_up, Done: False, Reward: 0, Agent Position: [74, 55]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 54]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 53]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 52]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [74, 51]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 50]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 49]
# Action: move_down, Done: False, Reward: 0, Agent Position: [74, 48]
# Action: move_left, Done: False, Reward: 0, Agent Position: [73, 48]
# Action: move_left, Done: False, Reward: 0, Agent Position: [72, 48]
# Action: move_left, Done: False, Reward: 0, Agent Position: [71, 48]
# Action: move_left, Done: False, Reward: 0, Agent Position: [70, 48]
# Action: move_left, Done: False, Reward: 0, Agent Position: [69, 48]
# Action: move_up, Done: False, Reward: 0, Agent Position: [69, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [68, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [67, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [66, 49]
# Action: move_left, Done: False, Reward: 0, Agent Position: [65, 49]
# Action: move_right, Done: False, Reward: 0, Agent Position: [66, 49]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 50]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 51]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 52]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 53]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [66, 54]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [66, 55]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 56]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 57]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 58]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 59]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 60]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 61]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 62]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 63]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 64]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 65]
# Action: move_right, Done: False, Reward: 0, Agent Position: [67, 65]
# Action: move_left, Done: False, Reward: 0, Agent Position: [66, 65]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 66]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 67]
# Action: move_up, Done: False, Reward: 0, Agent Position: [66, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [67, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [68, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [69, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [70, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [71, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [72, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [73, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [74, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [75, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [76, 68]
# Action: move_left, Done: False, Reward: 0, Agent Position: [75, 68]
# Action: move_left, Done: False, Reward: 0, Agent Position: [74, 68]
# Action: move_up, Done: False, Reward: 0, Agent Position: [74, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [75, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [76, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [77, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [78, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [79, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [80, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [81, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [82, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [83, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [84, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [85, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [86, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [87, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [88, 69]
# Action: move_right, Done: False, Reward: 1.0, Agent Position: [89, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [90, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [91, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [92, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [93, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [94, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [95, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [96, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [97, 69]
# Action: move_right, Done: False, Reward: 0, Agent Position: [98, 69]
# Action: move_down, Done: False, Reward: -1.0, Agent Position: [98, 68]
# Action: move_right, Done: False, Reward: 0, Agent Position: [99, 68]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 9.0
#
# Episode: 2
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 3
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 4
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 5
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 6
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 7
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 8
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 9
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 10
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 11
# Action: move_down, Done: False, Reward: 0, Agent Position: [100, 67]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 12
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 13
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 14
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 15
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 16
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 17
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 18
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 67]
# Total Reward: 0
#
# Episode: 19
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 68]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 20
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 21
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 22
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 68]
# Total Reward: 0
#
# Episode: 23
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 69]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 70]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 71]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 71]
# Total Reward: 0
#
# Episode: 24
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 72]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 73]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 74]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 75]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 76]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 77]
# Action: move_up, Done: False, Reward: 0, Agent Position: [100, 78]
# Action: move_left, Done: False, Reward: 0, Agent Position: [99, 78]
# Action: move_up, Done: False, Reward: 1.0, Agent Position: [99, 79]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 80]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 81]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 1.0
#
# Episode: 25
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 26
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 27
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 28
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 29
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 30
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 31
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 32
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 33
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 34
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 35
# Action: move_left, Done: False, Reward: 0, Agent Position: [99, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [98, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [97, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [96, 81]
# Action: move_up, Done: False, Reward: 0, Agent Position: [96, 82]
# Action: move_left, Done: False, Reward: 0, Agent Position: [95, 82]
# Action: move_right, Done: False, Reward: 0, Agent Position: [96, 82]
# Action: move_right, Done: False, Reward: 0, Agent Position: [97, 82]
# Action: move_right, Done: False, Reward: 1.0, Agent Position: [98, 82]
# Action: move_right, Done: False, Reward: 0, Agent Position: [99, 82]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 82]
# Total Reward: 1.0
#
# Episode: 36
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 82]
# Total Reward: 0
#
# Episode: 37
# Action: move_down, Done: False, Reward: 0, Agent Position: [100, 81]
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 38
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 39
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 40
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 41
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 42
# Action: move_right, Done: True, Reward: 0, Agent Position: [100, 81]
# Total Reward: 0
#
# Episode: 43
# Action: move_left, Done: False, Reward: 0, Agent Position: [99, 81]
# Action: move_down, Done: False, Reward: 0, Agent Position: [99, 80]
# Action: move_down, Done: False, Reward: 0, Agent Position: [99, 79]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 80]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 81]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 82]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 83]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 84]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 85]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 86]
# Action: move_up, Done: False, Reward: 0, Agent Position: [99, 87]
# Action: move_left, Done: False, Reward: 0, Agent Position: [98, 87]
# Action: move_up, Done: False, Reward: -1.0, Agent Position: [98, 88]
# Action: move_up, Done: False, Reward: 0, Agent Position: [98, 89]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 88]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 87]
# Action: move_down, Done: False, Reward: -1.0, Agent Position: [98, 86]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 85]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 84]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 83]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 82]
# Action: move_down, Done: False, Reward: 0, Agent Position: [98, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [97, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [96, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [95, 81]
# Action: move_left, Done: False, Reward: -1.0, Agent Position: [94, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [93, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [92, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [91, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [90, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [89, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [88, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [87, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [86, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [85, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [84, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [83, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [82, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [81, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [80, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [79, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [78, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [77, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [76, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [75, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [74, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [73, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [72, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [71, 81]
# Action: move_left, Done: False, Reward: -1.0, Agent Position: [70, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [69, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [68, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [67, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [66, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [65, 81]
# Action: move_left, Done: False, Reward: 0, Agent Position: [64, 81]
# Action: move_up, Done: False, Reward: 0, Agent Position: [64, 82]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [63, 82]
# Action: move_left, Done: False, Reward: 0, Agent Position: [62, 82]
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 82]
# Action: move_down, Done: False, Reward: 1.0, Agent Position: [61, 81]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 80]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 79]
# Action: move_down, Done: False, Reward: 0, Agent Position: [61, 78]
# Action: move_right, Done: False, Reward: 0, Agent Position: [62, 78]
# Action: move_down, Done: False, Reward: 0, Agent Position: [62, 77]
# Action: move_down, Done: False, Reward: 0, Agent Position: [62, 76]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 77]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 78]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 79]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 80]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 81]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 82]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 83]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 84]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 85]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 86]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 87]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 88]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 89]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 90]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 91]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 92]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 93]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 94]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 95]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 96]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 97]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 98]
# Action: move_up, Done: False, Reward: 0, Agent Position: [62, 99]
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: -2.0
#
# Episode: 44
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 45
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 46
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 47
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 48
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 49
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 50
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 51
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 52
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 53
# Action: move_up, Done: True, Reward: 0, Agent Position: [62, 100]
# Total Reward: 0
#
# Episode: 54
# Action: move_left, Done: False, Reward: 0, Agent Position: [61, 100]
# Action: move_up, Done: True, Reward: 0, Agent Position: [61, 100]
# Total Reward: 0
#
# Episode: 55
# Action: move_up, Done: True, Reward: 0, Agent Position: [61, 100]
# Total Reward: 0
#
# Episode: 56
# Action: move_up, Done: True, Reward: 0, Agent Position: [61, 100]
# Total Reward: 0
#
# Episode: 57
# Action: move_up, Done: True, Reward: 0, Agent Position: [61, 100]
# Total Reward: 0
#
# Episode: 58
# Action: move_up, Done: True, Reward: 0, Agent Position: [61, 100]
# Total Reward: 0
#
# Episode: 59
# Action: move_left, Done: False, Reward: 0, Agent Position: [60, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [59, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [58, 100]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [57, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [56, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [55, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [54, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [53, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [52, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [51, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [50, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [49, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [48, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [47, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [46, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [45, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [44, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [43, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [42, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [41, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [40, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [39, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [38, 100]
# Action: move_left, Done: False, Reward: 1.0, Agent Position: [37, 100]
# Action: move_up, Done: True, Reward: 0, Agent Position: [37, 100]
# Total Reward: 2.0
#
# Episode: 60
# Action: move_left, Done: False, Reward: 0, Agent Position: [36, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [35, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [34, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [33, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [32, 100]
# Action: move_left, Done: False, Reward: 0, Agent Position: [31, 100]
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 61
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 62
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 63
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 64
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 65
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 66
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 67
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 68
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 69
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 70
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 71
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 72
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 73
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 74
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 75
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 76
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 77
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 78
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 79
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 80
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 81
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 82
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 83
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 84
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 85
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 86
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 87
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 88
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 89
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 90
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 91
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 92
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 93
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 94
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 95
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 96
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 97
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 98
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 99
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
#
# Episode: 100
# Action: move_up, Done: True, Reward: 0, Agent Position: [31, 100]
# Total Reward: 0
